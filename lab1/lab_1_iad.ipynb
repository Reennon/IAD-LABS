# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('COVID_19 (2).xlsx', 'Sheet1')
#df

# %%
### Завдання 11
### Побудуйте графік кількості жінок, що перехворіли на грип, в залежності від віку.

data = df[(df['Gender']=='Female (Жінка)') & (df['Have you had influenza this year?']=='Yes')]
# sns.distplot(data['Age'])
#df.sort_values(by='Age',ascending=True)
plt.plot(data['Age'])
#plt.plot(x=data['Age'], data=data)
data
# s = data['Age'].sum()
# s.plot()

# data
# Out:
#                    Date time    Age          Gender                 Region  \
# 2    2020-09-20 11:23:15.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 18   2020-09-20 11:26:01.000  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 19   2020-09-20 11:26:01.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 29   2020-09-20 11:26:09.000  40-65  Female (Жінка)    Ukraine, Chernivtsi
# 33   2020-09-20 11:26:09.000  16-22  Female (Жінка)  Ukraine, Lviv (Львів)
# ...                      ...    ...             ...                    ...
# 3236 2020-12-30 17:13:45.090  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3240 2020-12-30 17:15:50.631  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3244 2020-12-30 17:19:07.649  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3277 2021-02-04 10:54:43.766  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3284 2021-02-16 10:06:47.526  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
#
#      Do you smoke? Have you had Covid`19 this year?  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('./datasets/COVID_19.xlsx', 'Sheet1')

# %%
df
# Out:
#                    Date time    Age          Gender                 Region  \
# 0    2020-09-20 11:23:15.000  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 1    2020-09-20 11:23:15.000  23-40  Female (Жінка)    Ukraine, Chernivtsi
# 2    2020-09-20 11:23:15.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3    2020-09-20 11:23:15.000  40-65  Male (Чоловік)    Ukraine, Chernivtsi
# 4    2020-09-20 11:23:15.000  16-22  Male (Чоловік)  Ukraine, Lviv (Львів)
# ...                      ...    ...             ...                    ...
# 3303 2021-03-02 09:56:35.956  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3304 2021-03-02 10:10:18.976  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3305 2021-03-04 11:03:43.786  40-65  Male (Чоловік)  Ukraine, Lviv (Львів)
# 3306 2021-03-04 11:04:30.416  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3307 2021-04-05 03:18:16.644  16-22  Female (Жінка)  Ukraine, Lviv (Львів)
#
#      Do you smoke? Have you had Covid`19 this year?  \
# ...

# %%
filtered_df = df[(df['Gender']=='Female (Жінка)') & (df['Have you had influenza this year?']=='Yes')]
filtered_df
# Out:
#                    Date time    Age          Gender                 Region  \
# 2    2020-09-20 11:23:15.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 18   2020-09-20 11:26:01.000  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 19   2020-09-20 11:26:01.000  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 29   2020-09-20 11:26:09.000  40-65  Female (Жінка)    Ukraine, Chernivtsi
# 33   2020-09-20 11:26:09.000  16-22  Female (Жінка)  Ukraine, Lviv (Львів)
# ...                      ...    ...             ...                    ...
# 3236 2020-12-30 17:13:45.090  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3240 2020-12-30 17:15:50.631  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
# 3244 2020-12-30 17:19:07.649  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3277 2021-02-04 10:54:43.766  23-40  Female (Жінка)  Ukraine, Lviv (Львів)
# 3284 2021-02-16 10:06:47.526  40-65  Female (Жінка)  Ukraine, Lviv (Львів)
#
#      Do you smoke? Have you had Covid`19 this year?  \
# ...

# %%
sns.set_style('darkgrid')
sns.histplot(x=filtered_df['Age'], data=filtered_df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>
